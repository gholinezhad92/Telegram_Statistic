# %%
import json
from collections import Counter
from hazm import word_tokenize, Normalizer
from wordcloud import WordCloud

# %%
with open('../data/online.json') as f:
    data = json.load(f)

# %%
msg_iter = iter(data['messages'])

# %%
stop_words = open('stopwords.txt').readlines()
stop_words =list(map(str.strip, stop_words))
stop_words = list(map(normalizer.normalize, stop_words))

# %%
text_content = ''

for msg in data['messages']:
    if type(msg['text']) is str:
        tokens = word_tokenize(msg['text'])
        tokens = list(filter(lambda item: item not in stop_words, tokens))
        text_content += f" {' '.join(tokens)}"

# %%
#Counter(word_tokenize(text_content)).most_common()

# %%
normalizer = Normalizer()
text_content = normalizer.normalize(text_content)

# %%
text_content = arabic_reshaper.reshape(text_content)
text_content = get_display(text_content)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_2188/1919260292.py in <module>
#       1 text_content = arabic_reshaper.reshape(text_content)
# ----> 2 text_content = get_display(text_content)
#
# ~/anaconda3/envs/Telestat/lib/python3.8/site-packages/bidi/algorithm.py in get_display(unicode_or_str, encoding, upper_is_rtl, base_dir, debug)
#     646     resolve_weak_types(storage, debug)
#     647     resolve_neutral_types(storage, debug)
# --> 648     resolve_implicit_levels(storage, debug)
#     649     reorder_resolved_levels(storage, debug)
#     650     apply_mirroring(storage, debug)
#
# ~/anaconda3/envs/Telestat/lib/python3.8/site-packages/bidi/algorithm.py in resolve_implicit_levels(storage, debug)
#     463         for _ch in chars:
#     464             # only those types are allowed at this stage
# --> 465             #assert _ch['type'] in ('L', 'R', 'EN', 'AN'),\
#     466             #       '%s not allowed here' % _ch['type']
#     467
#
# AssertionError:  not allowed here

# %%
wordcloud = WordCloud(font_path='./BHoma.ttf', background_color='white', width=400,
    height=200,).generate(text_content)

# %%
#tokens = word_tokenize(text_content)

# %%
#text = 'salam ali hi how are u'
#wordcloud = WordCloud(background_color='White').generate(text_content)

# %%
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
Counter(text_content.split()).most_common()
# Out:
# [('و', 916),
#  ('رو', 824),
#  ('که', 752),
#  ('به', 501),
#  ('از', 495),
#  ('این', 485),
#  ('هم', 450),
#  ('من', 400),
#  ('یه', 322),
#  ('با', 274),
#  ('سلام', 272),
#  ('در', 240),
#  ('برای', 240),
#  ('تو', 226),
#  ('ولی', 223),
#  ('کلاس', 218),
#  ('خیلی', 203),
#  ('میشه', 193),
#  ('ها', 190),
#  ('اون', 181),
#  ('اگه', 172),
#  ('تا', 171),
#  ('شما', 170),
#  ('یا', 164),
#  ('هست', 163),
#  ('کنم', 159),
#  ('ممنون', 156),
#  ('دوستان', 155),
#  ('کردم', 150),
#  ('توی', 147),
#  ('باید', 145),
#  ('یک', 145),
#  ('دیگه', 137),
#  ('کنید', 135),
#  ('نصب', 129),
#  ('باشه', 124),
#  ('نه', 123),
#  ('جلسه', 122),
#  ('بعد', 119),
#  ('الان', 116),
#  ('باز', 103),
#  ('های', 103),
#  ('وقتی', 99),
#  ('می', 99),
#  ('هر', 98),
#  ('بچه', 97),
#  ('بود', 95),
#  ('اول', 94),
#  ('علی', 94),
#  ('کار', 94),
#  ('داره', 93),
#  ('شده', 93),
#  ('شد', 93),
#  ('فکر', 92),
#  ('استفاده', 90),
#  ('همه', 89),
#  ('میکنم', 87),
#  ('کسی', 87),
#  ('نیست', 85),
#  ('همین', 82),
#  ('یعنی', 82),
#  ('دانلود', 82),
#  ('منم', 80),
#  ('همون', 80),
#  ('مرسی', 78),
#  ('پایتون', 78),
#  ('اگر', 76),
#  ('هفته', 76),
#  ('چون', 75),
#  ('اینکه', 74),
#  ('گروه', 73),
#  ('حالا', 73),
#  ('درست', 72),
#  ('فایل', 71),
#  ('خب', 70),
#  ('بله', 69),
#  ('چرا', 66),
#  ('شروع', 66),
#  ('تمرین', 66),
#  ('ما', 66),
#  ('دو', 65),
#  ('خود', 65),
#  ('ارور', 64),
#  ('سوال', 64),
#  ('اما', 63),
#  ('یکی', 62),
#  ('کنه', 61),
#  ('فقط', 60),
#  ('مشکل', 59),
#  ('مثلا', 59),
#  ('انجام', 58),
#  ('؟', 55),
#  ('امروز', 54),
#  ('.', 54),
#  (':)', 54),
#  ('اره', 54),
#  ('میده', 54),
#  ('دارم', 53),
#  ('ی', 53),
#  ('واقعا', 53),
#  ('البته', 53),
#  ('کد', 53),
#  ('لیست', 52),
#  ('بشه', 51),
#  ('چه', 51),
#  ('،', 50),
#  ('ای', 50),
#  ('داخل', 50),
#  ('چیزی', 50),
#  ('کردن', 50),
#  ('...', 50),
#  ('ممنونم', 50),
#  ('پس', 50),
#  ('خوب', 49),
#  ('اینجا', 48),
#  ('داده', 48),
#  ('داشته', 48),
#  ('سایت', 47),
#  ('دوباره', 47),
#  ('کلا', 47),
#  ('چی', 46),
#  ('لینوکس', 46),
#  ('جان', 46),
#  ('وقت', 45),
#  ('ک', 45),
#  ('میکنه', 45),
#  ('وارد', 44),
#  ('واسه', 44),
#  ('حل', 43),
#  ('ببخشید', 43),
#  ('آقای', 43),
#  ('دوره', 43),
#  ('اصلا', 42),
#  ('پاک', 42),
#  (':))', 42),
#  ('متوجه', 42),
#  ('لطفا', 41),
#  ('دانشگاه', 41),
#  ('پیدا', 41),
#  ('روی', 41),
#  ('ساعت', 41),
#  ('بیشتر', 40),
#  ('تغییر', 40),
#  ('تابع', 40),
#  ('لینک', 39),
#  ('حجازی', 39),
#  ('کنیم', 39),
#  ('دستور', 39),
#  ('شدم', 38),
#  ('آقا', 38),
#  ('بدون', 37),
#  ('پیش', 37),
#  ('گفتن', 37),
#  ('جوپیتر', 37),
#  ('بچه\u200cها', 37),
#  ('خط', 37),
#  ('حتما', 36),
#  ('اینو', 36),
#  ('شاید', 35),
#  ('دقیقا', 35),
#  ('چند', 35),
#  ('چک', 34),
#  ('جواب', 34),
#  ('نمیشه', 34),
#  ('کرده', 34),
#  ('نداره', 33),
#  ('امتحان', 33),
#  ('تموم', 33),
#  ('یاد', 33),
#  ('کنید.', 33),
#  ('مورد', 33),
#  ('خودم', 32),
#  ('ویندوز', 32),
#  ('کرد', 32),
#  ('قسمت', 32),
#  ('x', 32),
#  ('مثل', 31),
#  ('اینه', 31),
#  ('توضیح', 31),
#  ('سر', 31),
#  ('میاد', 31),
#  ('بوده', 31),
#  ('درسته', 31),
#  ('هنوز', 31),
#  ('wsl', 30),
#  ('اونجا', 30),
#  ('راه', 30),
#  ('قبل', 30),
#  ('عالی', 30),
#  ('کنی', 30),
#  ('پیام', 30),
#  ('مشکلی', 29),
#  ('هیچ', 29),
#  ('گفتم', 29),
#  ('جلسات', 29),
#  ('ران', 29),
#  ('تعریف', 29),
#  ('برنامه', 28),
#  ('بخیر', 28),
#  ('قبلا', 28),
#  ('بار', 28),
#  ('قرار', 28),
#  ('خواهش', 28),
#  ('جا', 28),
#  ('خروجی', 28),
#  ('داریم', 28),
#  ('برا', 28),
#  ('=', 28),
#  ('نظر', 28),
#  ('کن', 27),
#  ('😂😂😂', 27),
#  ('ژوپیتر', 27),
#  ('ترمینال', 27),
#  ('بودن', 27),
#  ('میشم', 27),
#  ('فعال', 26),
#  ('آره', 26),
#  ('حتی', 26),
#  ('رشته', 26),
#  ('دسترسی', 26),
#  ('😂', 26),
#  ('دارن', 26),
#  ('میخوام', 26),
#  ('خطا', 25),
#  ('خوبی', 25),
#  ('نمیدونم', 25),
#  ('می\u200cکنم', 25),
#  ('بالا', 25),
#  ('اشتباه', 25),
#  ('کل', 25),
#  ('علیرضا', 25),
#  ('روز', 25),
#  ('جای', 25),
#  ('بعدش', 24),
#  ('لطف', 24),
#  ('اوکی', 24),
#  ('برام', 24),
#  ('دارید', 24),
#  ('😅', 24),
#  ('جدید', 24),
#  ('اسم', 24),
#  ('را', 24),
#  ('داشتم', 23),
#  ('is', 23),
#  ('نشده', 23),
#  ('احتمالا', 23),
#  ('کامل', 23),
#  ('خودتون', 23),
#  ('استاد', 23),
#  ('میزنم', 23),
#  ('شنبه', 23),
#  ('رفع', 22),
#  ('سری', 22),
#  ('بده', 22),
#  ('کجا', 22),
#  ('سرچ', 22),
#  ('همیشه', 22),
#  ('خودش', 22),
#  ('بزنید', 22),
#  ('بودم', 22),
#  ('a', 22),
#  ('گوگل', 21),
#  ('دیروز', 21),
#  ('دیدم', 21),
#  ('سیستم', 21),
#  ('نام', 21),
#  ('ماشین', 21),
#  ('کنن', 21),
#  ('اش', 21),
#  ('کدوم', 21),
#  ('کم', 20),
#  ('نشد', 20),
#  ('سلام.', 20),
#  ('ممکنه', 20),
#  ('آخر', 20),
#  ('🙏', 20),
#  ('تازه', 20),
#  ('کمک', 20),
#  ('زیاد', 20),
#  ('نظرم', 20),
#  ('دست', 20),
#  ('کنین', 20),
#  ('چقدر', 20),
#  ('بهش', 20),
#  ('ادامه', 20),
#  ('باشید', 20),
#  ('بر', 20),
#  ('نمی', 20),
#  ('اضافه', 20),
#  ('می\u200cکنه', 20),
#  ('فردا', 20),
#  ('عقب', 19),
#  ('شدن', 19),
#  ('درس', 19),
#  ('نگاه', 19),
#  ('اینجوری', 19),
#  ('میتونه', 19),
#  ('راهنمایی', 19),
#  ('نیاز', 19),
#  ('بسیار', 19),
#  ('هست.', 19),
#  ('چیه؟', 19),
#  ('اطلاع', 19),
#  ('نمیتونم', 19),
#  ('فیلتر', 19),
#  ('ست', 19),
#  ('برگزار', 19),
#  ('متاسفانه', 18),
#  ('بقیه', 18),
#  ('عوض', 18),
#  ('موقع', 18),
#  ('صورت', 18),
#  ('چجوری', 18),
#  ('چیز', 18),
#  ('روش', 18),
#  ('بحث', 18),
#  ('اوبونتو', 18),
#  ('code', 18),
#  ('اینا', 18),
#  ('مربوط', 18),
#  ('سه', 18),
#  ('وجود', 18),
#  ('+', 18),
#  ('نیست.', 18),
#  ('ذخیره', 18),
#  ('فیلترشکن', 18),
#  ('ینی', 18),
#  ('ایران', 18),
#  ('کپی', 17),
#  (',', 17),
#  ('گفته', 17),
#  ('بازم', 17),
#  ('بدم', 17),
#  (':', 17),
#  ('کلی', 17),
#  ('بعدا', 17),
#  ('پروژه', 17),
#  ('خودشون', 17),
#  ('نمیکنه', 17),
#  ('هستن', 17),
#  ('۲', 17),
#  ('فک', 17),
#  ('دوست', 17),
#  ('ضبط', 17),
#  ('ببینم', 17),
#  ('دقیقه', 17),
#  ('راحت', 17),
#  ('۱', 17),
#  ('میدونه', 17),
#  ('فرق', 17),
#  ('حالت', 17),
#  ('جایی', 17),
#  ('بهتر', 17),
#  ('خارج', 17),
#  ('جلو', 17),
#  ('خونه', 17),
#  ('قبلی', 16),
#  ('نکردم', 16),
#  ('تمام', 16),
#  ('چطوری', 16),
#  ('می\u200cشه', 16),
#  ('کردین', 16),
#  ('کردید', 16),
#  ('دادن', 16),
#  ('مگه', 16),
#  ('پی', 16),
#  ('بهتره', 16),
#  ('جمع', 16),
#  ('صرفا', 16),
#  ('خیر', 16),
#  ('تر', 16),
#  ('وصل', 16),
#  ('مهم', 16),
#  ('است', 16),
#  ('میدم', 16),
#  ('پوشه', 16),
#  ('اجرا', 16),
#  ('حساب', 16),
#  ('ب', 16),
#  ('-', 16),
#  ('پرینت', 16),
#  ('set', 16),
#  ('یکشنبه', 16),
#  ('هزینه', 16),
#  ('معمولا', 15),
#  ('ایندکس', 15),
#  ('بهم', 15),
#  ('خوبه', 15),
#  ('عدد', 15),
#  ('موافقم', 15),
#  ('داره.', 15),
#  ('تبدیل', 15),
#  ('کمی', 15),
#  ('لرنینگ', 15),
#  ('نیستم', 15),
#  ('طول', 15),
#  ('بابت', 15),
#  ('for', 15),
#  ('می\u200cتونید', 15),
#  ('خدا', 15),
#  ('منفی', 15),
#  ('دیکشنری', 15),
#  ('تلگرام', 15),
#  ('رفتم', 14),
#  ('هستش', 14),
#  ('نبود', 14),
#  ('بریم', 14),
#  ('دادین', 14),
#  ('سرعت', 14),
#  ('پیشنهاد', 14),
#  ('!', 14),
#  ('چندتا', 14),
#  ('بدید', 14),
#  ('حرف', 14),
#  ('میگه', 14),
#  ('یکم', 14),
#  (':)))', 14),
#  ('vscode', 14),
#  ('هایی', 14),
#  ('گرفتم', 14),
#  ('گرم', 14),
#  ('اخر', 14),
#  ('کنم.', 14),
#  ('دوم', 14),
#  ('مونده', 14),
#  ('گیت', 14),
#  ('کاش', 14),
#  ('👍👍', 14),
#  ('وقتتون', 14),
#  ('سلام،', 14),
#  ('بیاد', 14),
#  ('هست؟', 14),
#  ('کی', 14),
#  ('هش', 14),
#  ('مرور', 14),
#  ('حلقه', 14),
#  ('تشکیل', 14),
#  ('میتونید', 13),
#  ('گزینه', 13),
#  ('ندارم', 13),
#  ('صفر', 13),
#  ('فهمیدم', 13),
#  ('حد', 13),
#  ('درد', 13),
#  ('باشه.', 13),
#  ('in', 13),
#  ('کامپیوتر', 13),
#  ('میگن', 13),
#  ('بابا', 13),
#  ('جالب', 13),
#  ('نتیجه', 13),
#  ('کورس', 13),
#  ('فیلم', 13),
#  ('تونید', 13),
#  ('زیر', 13),
#  ('ماه', 13),
#  ('زدم', 13),
#  ('دایرکتوری', 13),
#  ('سخت', 13),
#  ('کاری', 13),
#  ('نتونستم', 13),
#  ('بدین', 13),
#  ('بود.', 13),
#  ('میشه؟', 13),
#  ('میخواستم', 13),
#  ('if', 13),
#  ('میگم', 13),
#  ('بعدی', 13),
#  ('دارین', 12),
#  ('کنم؟', 12),
#  ('کنار', 12),
#  ('مباحث', 12),
#  ('امیدوارم', 12),
#  ('ازش', 12),
#  ('صحبت', 12),
#  ('نفر', 12),
#  ('بخش', 12),
#  ('😂😂', 12),
#  ('ثبت', 12),
#  ('اها', 12),
#  ('شه', 12),
#  ('کردم،', 12),
#  ('زده', 12),
#  ('میدونم', 12),
#  ('vs', 12),
#  ('داد', 12),
#  ('مشخص', 12),
#  ('شد.', 12),
#  ('اشکال', 12),
#  ('استرینگ', 12),
#  ('گذاشتن', 12),
#  ('تعداد', 12),
#  ('نوع', 12),
#  ('شکن', 12),
#  ('عنوان', 12),
#  ('متغیر', 12),
#  ('مطالب', 12),
#  ('زودتر', 12),
#  ('همگی', 11),
#  ('دادم', 11),
#  ('خاطر', 11),
#  ('بشید', 11),
#  ('برنامه\u200cنویسی', 11),
#  ('برم', 11),
#  ('سعی', 11),
#  ('زوم', 11),
#  ('بین', 11),
#  ('۴', 11),
#  ('دوتا', 11),
#  ('میشن', 11),
#  ('بستگی', 11),
#  ('ریکورد', 11),
#  ('براش', 11),
#  ('نداشته', 11),
#  ('🌹', 11),
#  ('پایین', 11),
#  ('می\u200cکنه.', 11),
#  ('لازم', 11),
#  ('اونم', 11),
#  ('فلش', 11),
#  ('میرم', 11),
#  ('cd', 11),
#  ('2', 11),
#  ('داشت', 11),
#  ('بزن', 11),
#  ('🙏🏻', 11),
#  ('هاب', 11),
#  ('دیشب', 11),
#  ('اعمال', 11),
#  ('میکنیم', 11),
#  ('هارو', 11),
#  ('حرکت', 11),
#  ('میتونی', 11),
#  ('اینترنت', 11),
#  ('مثال', 11),
#  ('ترتیب', 11),
#  ('زمان', 11),
#  ('فانکشن', 11),
#  ('صفحه', 11),
#  ('ببینید', 11),
#  ('دی', 11),
#  ('ضرب', 11),
#  ('==', 11),
#  ('0:', 11),
#  ('عضو', 11),
#  ('زبان', 11),
#  ('y', 11),
#  ('کتاب', 11),
#  ('خبر', 11),
#  ('والا', 10),
#  ('کنین.', 10),
#  ('string', 10),
#  ('👍', 10),
#  ('شرکت', 10),
#  ('بهترین', 10),
#  ('موارد', 10),
#  ('خوبیه', 10),
#  ('فعلا', 10),
#  ('مختلف', 10),
#  ('میکردم', 10),
#  ('داری', 10),
#  ('jupyter', 10),
#  ('؟!', 10),
#  ('مطرح', 10),
#  ('رفرنس', 10),
#  ('بگم', 10),
#  ('باشیم', 10),
#  ('آپلود', 10),
#  ('کردم.', 10),
#  ('بگید', 10),
#  ('ورژن', 10),
#  ('علامت', 10),
#  ('بلد', 10),
#  ('خواستم', 10),
#  ('اونو', 10),
#  ('جدا', 10),
#  ('مرحله', 10),
#  ('راستش', 10),
#  ('بخاطر', 10),
#  ('نوشته', 10),
#  ('نداریم', 10),
#  ('متفاوت', 10),
#  ('درسته؟', 10),
#  ('همچین', 10),
#  ('طبق', 10),
#  ('نه.', 10),
#  ('منظورم', 10),
#  ('طریق', 10),
#  ('محیط', 10),
#  ('کاملا', 10),
#  ('ازتون', 10),
#  ('حداقل', 10),
#  ('منو', 10),
#  ('نوت', 10),
#  ('میتونم', 10),
#  ('نت', 10),
#  ('آدرس', 10),
#  (')', 10),
#  ('سریع', 10),
#  ('بعضی', 10),
#  ('شرط', 10),
#  ('سوالی', 10),
#  ('تک', 10),
#  ('بی', 10),
#  ('سال', 10),
#  ('اپلای', 10),
#  ('پین', 9),
#  ('ویدیو', 9),
#  ('باعث', 9),
#  ('کرد؟', 9),
#  ('zsh', 9),
#  ('چی؟', 9),
#  ('هیچی', 9),
#  ('اولین', 9),
#  ('جزوه', 9),
#  ('خالی', 9),
#  ('مطلب', 9),
#  (':))))', 9),
#  ('وگرنه', 9),
#  (':(', 9),
#  ('نمیده', 9),
#  ('ممنون🙏', 9),
#  ('چیکار', 9),
#  ('اتفاق', 9),
#  ('چطور', 9),
#  ('عالیه', 9),
#  ('شد؟', 9),
#  ('نیم', 9),
#  ('باشه؟', 9),
#  ('میشه.', 9),
#  ('تشکر', 9),
#  ('اتفاقا', 9),
#  ('انلاین', 9),
#  ('پوستهٔ', 9),
#  ('base', 9),
#  ('مال', 9),
#  ('عه', 9),
#  ('گفت', 9),
#  ('tmp', 9),
#  ('نباید', 9),
#  ('میشد', 9),
#  ('آپدیت', 9),
#  ('مسیر', 9),
#  ('هفت', 9),
#  ('بازه', 9),
#  ('استور', 9),
#  ('مرورگر', 9),
#  ('هستم', 9),
#  ('نشون', 9),
#  ('میره', 9),
#  ('میتونیم', 9),
#  ('نمیاد', 9),
#  ('1', 9),
#  ('آها', 9),
#  ('conda', 9),
#  ('برید', 9),
#  ('واقع', 9),
#  ('راهنماییم', 9),
#  ('میکنم.', 9),
#  ('رمز', 9),
#  ('😁', 9),
#  ('گیر', 9),
#  ('بنظرم', 9),
#  ('🙏🙏', 9),
#  ('قراره', 9),
#  ('نگران', 9),
#  ('فونت', 9),
#  ('to', 9),
#  ('قطعا', 9),
#  ('شماره', 9),
#  ('جلسه\u200cی', 9),
#  ('کشور', 9),
#  ('فریدونی', 9),
#  ('یادگیری', 9),
#  ('چیه', 9),
#  ('ربع', 9),
#  ('CS', 9),
#  ('copy', 9),
#  ('خوش', 9),
#  ('سپاس', 9),
#  ('اين', 8),
#  ('کردی', 8),
#  ('دور', 8),
#  ('مستقیم', 8),
#  ('روشن', 8),
#  ('خاصی', 8),
#  ('ایجاد', 8),
#  ('بنویسم', 8),
#  ('میدن', 8),
#  ('جوین', 8),
#  ('ربطی', 8),
#  ('😂😂😂😂', 8),
#  ('4', 8),
#  ('نوشتم', 8),
#  ('۱۰', 8),
#  ('pdf', 8),
#  ('وی', 8),
#  ('خودت', 8),
#  ('بدیم', 8),
#  ('رایگان', 8),
#  ('بدن', 8),
#  ('تقریبا', 8),
#  ('اوکیه', 8),
#  ('درگیر', 8),
#  ('نیازی', 8),
#  ('ساده', 8),
#  ('صورتی', 8),
#  ('حدودا', 8),
#  ('اومدم', 8),
#  ('کنیم؟', 8),
#  ('الآن', 8),
#  ('نیس', 8),
#  ('دیگه.', 8),
#  ('می\u200cشه.', 8),
#  ('اشتباهی', 8),
#  ('نداشتم', 8),
#  ('ساخته', 8),
#  ('بنویسید', 8),
#  ('چیزا', 8),
#  ('اخه', 8),
#  ('اشاره', 8),
#  ('انتخاب', 8),
#  ('اومد', 8),
#  ('🤔', 8),
#  ('اهان', 8),
#  ('دلیل', 8),
#  ('چنین', 8),
#  ('ده', 8),
#  ('صبر', 8),
#  ('داشتن', 8),
#  ('اقای', 8),
#  ('بزنم', 8),
#  ('فرض', 8),
#  ('می\u200cتونه', 8),
#  ('بشه.', 8),
#  ('بدی', 8),
#  ('tuple', 8),
#  ('کدی', 8),
#  ('متغییر', 8),
#  ('7', 8),
#  ('باشه،', 8),
#  ('۳', 8),
#  ('ه', 8),
#  ('میگیره', 8),
#  ('مثبت', 8),
#  ('بذاری', 8),
#  ('بره', 8),
#  ('امکان', 8),
#  ('قرمز', 8),
#  ('دستی', 8),
#  ('اولش', 8),
#  ('براتون', 8),
#  ('خودمون', 8),
#  ('آیا', 8),
#  ('شکلی', 8),
#  ('*', 8),
#  ('تلاش', 8),
#  ("'", 8),
#  ('ورودی', 8),
#  ('the', 8),
#  ('توضیحات', 8),
#  ('اعداد', 8),
#  ('نمیشم', 8),
#  ('جداگانه', 8),
#  ('ریزی', 8),
#  ('کارت', 8),
#  ('درایو', 8),
#  ('return', 8),
#  ('دیر', 8),
#  ('تایم', 8),
#  ('رب', 8),
#  ('فاند', 8),
#  ('طور', 7),
#  ('كه', 7),
#  ('جزو', 7),
#  ('مجبور', 7),
#  ('اپدیت', 7),
#  ('اکی', 7),
#  ('نرم', 7),
#  ('کنیم،', 7),
#  ('هست،', 7),
#  ('كلاس', 7),
#  ('بخوام', 7),
#  ('تجربه', 7),
#  ('مسئله', 7),
#  ('بتونم', 7),
#  ('مهمه', 7),
#  ('بیتی', 7),
#  ('رم', 7),
#  ('چقد', 7),
#  ('برابر', 7),
#  ('انگار', 7),
#  ('ام', 7),
#  ('بسته', 7),
#  ('بهتون', 7),
#  ('تدریس', 7),
#  ('افتاده', 7),
#  ('موافق', 7),
#  ('قشنگ', 7),
#  ('بتونه', 7),
#  ('دفعه', 7),
#  ('دقیق', 7),
#  ('حجم', 7),
#  ('حس', 7),
#  ('کارای', 7),
#  ('توصیه', 7),
#  ('نسخه', 7),
#  ('باشن', 7),
#  ('گذاشتی', 7),
#  ('ubuntu', 7),
#  ('آخه', 7),
#  ('بدونم', 7),
#  ('شبیه', 7),
#  ('بگه', 7),
#  ('3', 7),
#  ('باشی', 7),
#  ('۵', 7),
#  ('گرفت', 7),
#  ('پر', 7),
#  ('عجیب', 7),
#  ('ببین', 7),
#  ('ویژگی', 7),
#  ('راجع', 7),
#  ('پیاده\u200cسازی', 7),
#  ('نبودم', 7),
#  ('معرفی', 7),
#  ('تغییرات', 7),
#  ('می\u200cکنید', 7),
#  ('رسانی', 7),
#  ('مینویسه', 7),
#  ('بگین', 7),
#  ('همچنان', 7),
#  ('اونایی', 7),
#  ('ان', 7),
#  ('کلید', 7),
#  ('اینطوری', 7),
#  ('داخلش', 7),
#  ('بشم', 7),
#  ('٠', 7),
#  ('نقطه', 7),
#  ('نکنید', 7),
#  ('نظرتون', 7),
#  ('بوک', 7),
#  ('تنها', 7),
#  ('بجای', 7),
#  ('ارسال', 7),
#  ('توش', 7),
#  ('میگیرم', 7),
#  ('نیست،', 7),
#  ('لپ', 7),
#  ('سراغ', 7),
#  ('دمت', 7),
#  ('انقدر', 7),
#  ('مقایسه', 7),
#  ('هرچی', 7),
#  ('شکل', 7),
#  ('گوشی', 7),
#  ('شده.', 7),
#  ('اف', 7),
#  ('درستش', 7),
#  ('دریافت', 7),
#  ('یکسری', 7),
#  ('الگوریتم', 7),
#  ('میذارم', 7),
#  ('🧡', 7),
#  ('تهران', 7),
#  ('"', 7),
#  ('برک', 7),
#  ('کانادا', 7),
#  ('حذف', 6),
#  ('افزار', 6),
#  ('بگیرم', 6),
#  ('اطلاعات', 6),
#  ('کرد.', 6),
#  ('کامنت', 6),
#  ('پاسخ', 6),
#  ('صدا', 6),
#  ('۶۴', 6),
#  ('ساپورت', 6),
#  ('بیت', 6),
#  ('درک', 6),
#  ('👍🏻', 6),
#  ('مبتدی', 6),
#  ('ایشون', 6),
#  ('تهش', 6),
#  ('github', 6),
#  ('نمیکنم', 6),
#  ('file', 6),
#  ('مرتبط', 6),
#  ('کورسرا', 6),
#  ('b', 6),
#  ('می\u200cخوام', 6),
#  ('دستورات', 6),
#  ('میگین', 6),
#  ('همینه', 6),
#  ('😄', 6),
#  ('قبلش', 6),
#  ('تنظیمات', 6),
#  ('بپرسید', 6),
#  ('گذاشته', 6),
#  ('لینکش', 6),
#  ('۴۰', 6),
#  ('env', 6),
#  ('install', 6),
#  ('ایا', 6),
#  ('یادم', 6),
#  ('موضوع', 6),
#  ('مدت', 6),
#  ('ماکروسافت', 6),
#  ('نباشه', 6),
#  ('اصلی', 6),
#  ('گذاشتم', 6),
#  ('اینم', 6),
#  ('همینطور', 6),
#  ('بپرسید.', 6),
#  ('فرقی', 6),
#  ('راست', 6),
#  ('می\u200cکنن', 6),
#  ('مراحل', 6),
#  ('برو', 6),
#  ('رو.', 6),
#  ('مدیریت', 6),
#  ('خطای', 6),
#  ('۵۰۰', 6),
#  ('بپرسم', 6),
#  ('نشه', 6),
#  ('بتونیم', 6),
#  ('میکنی', 6),
#  ('شده؟', 6),
#  ('مخابرات', 6),
#  ('مقدار', 6),
#  ('خلاصه', 6),
#  ('لینکی', 6),
#  ('سوالم', 6),
#  ('چاپ', 6),
#  ('نکنم', 6),
#  ('دونه', 6),
#  ('c', 6),
#  ('اصن', 6),
#  ('بگی', 6),
#  ('میخوای', 6),
#  ('آبجکت', 6),
#  ('تب', 6),
#  ('عمل', 6),
#  ('رنگ', 6),
#  ('شدم.', 6),
#  ('ممنون.', 6),
#  ('خوندم', 6),
#  ('اسمش', 6),
#  ('نماد', 6),
#  ('گذاری', 6),
#  ('نیستن', 6),
#  ('حال', 6),
#  ('اینکارو', 6),
#  ('ارزش', 6),
#  ('Python', 6),
#  ('elif', 6),
#  ('زنگ', 6),
#  ('میده.', 6),
#  ('بگیرید', 6),
#  ('یافت', 6),
#  ('i', 6),
#  ('print("it', 6),
#  ('break', 6),
#  ('بودین', 6),
#  ('ببینید.', 6),
#  ('داکیومنتیشن', 6),
#  ('g', 6),
#  ('pwd', 6),
#  ('یادمه', 6),
#  ('id', 6),
#  ('میگید', 6),
#  ('حافظه', 6),
#  ('کنه.', 6),
#  ('سطح', 6),
#  ('کننده', 6),
#  ('k', 6),
#  ('سیو', 6),
#  ('class', 6),
#  ('بگذره', 6),
#  ('عزیز', 6),
#  ('جبران', 6),
#  ('سایفون', 6),
#  ('oop', 6),
#  ('آزاد', 6),
#  ('آموزش', 6),
#  ('داشتیم', 6),
#  ('ادونس', 6),
#  ('چ', 6),
#  ('دکتر', 6),
#  ('مصاحبه', 6),
#  ('وبینار', 6),
#  ('انگیزه', 6),
#  ('ولي', 5),
#  ('or', 5),
#  ('داک', 5),
#  ('امکانش', 5),
#  ('باقی', 5),
#  ('كردم', 5),
#  ('ممنونم.', 5),
#  ...]
